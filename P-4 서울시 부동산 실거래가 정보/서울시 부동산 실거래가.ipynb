# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
# %ls apartment_data/
# Out:
# ls: apartment_data/: No such file or directory

# %%
df = pd.read_csv("/Users/hajun/Desktop/대쉬보드 프로젝트/P-4 서울시 부동산 실거래가 정보/서울시 부동산 실거래가 정보.csv", encoding="cp949")

# %%
df.tail(10)
# Out:
#          접수연도 자치구명  법정동코드  법정동명           건물명       계약일  물건금액(만원)  건물면적(㎡)  \
# 1048565  2017  동작구  10200   상도동           NaN  20170304     25800    35.50
# 1048566  2017  강서구  10400   가양동            강변  20170304     36800    49.50
# 1048567  2017  성북구  13500   종암동           NaN  20170304     26000    45.53
# 1048568  2017  동작구  10900  신대방동  동우맨션(360-80)  20170304     23800    56.43
# 1048569  2017  구로구  10300  가리봉동           NaN  20170304     31050    39.99
# 1048570  2017  은평구  10500   구산동          갈현현대  20170304     35000   114.95
# 1048571  2017  구로구  10800   오류동           프리가  20170304      9900    20.73
# 1048572  2017  성북구  13900   석관동            두산  20170304     35000    59.97
# 1048573  2017  은평구  10500   구산동    플러스빌(2-16)  20170304     14800    26.67
# 1048574  2017  강서구  10400   가양동         가양6단지  20170304     38800    49.50
#
#          토지면적(㎡)     층    건축년도   건물용도 신고한 개업공인중개사 시군구명
# 1048565    56.00   NaN  1983.0  단독다가구              NaN
# ...
